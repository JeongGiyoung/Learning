# %%
from youtube_transcript_api import YouTubeTranscriptApi
# 오징어 게임 url https://www.youtube.com/watch?v=ysz5Sl3msyk
 
srt = YouTubeTranscriptApi.get_transcript("ysz5Sl3msyk", languages=['ko'])
 
with open("subtitles.txt", "w", encoding='utf-8') as f:  
    for i in srt:
        # writing each element of srt on a new line
        f.write("{}\n".format(i))

# %%
srt = YouTubeTranscriptApi.get_transcript("ysz5Sl3msyk", languages=['ko'])
 
for i in srt :
    print(i)
# Out:
# {'text': '저는...', 'start': 0.0, 'duration': 0.584}
# {'text': "'블랙핑크: 세상을 밝혀라'  ", 'start': 0.585, 'duration': 1.808}
# {'text': '[정재 취향 궁금하면 드루와]\n그거 못 했어요!', 'start': 2.394, 'duration': 1.58}
# {'text': '[마이_넷플릭스]', 'start': 3.975, 'duration': 2.147}
# {'text': '안녕하세요!', 'start': 6.123, 'duration': 1.263}
# {'text': "'오징어 게임'의 이정재", 'start': 7.387, 'duration': 1.623}
# {'text': '박해수', 'start': 9.011, 'duration': 0.771}
# {'text': '위하준', 'start': 9.783, 'duration': 0.62}
# {'text': '정호연입니다.', 'start': 10.404, 'duration': 0.774}
# {'text': "지금부터 '오징어 게임' 팀의", 'start': 11.179, 'duration': 2.394}
# {'text': '취향을 가득 담은', 'start': 13.574, 'duration': 1.384}
# {'text': "'마이 넷플릭스'가", 'start': 14.959, 'duration': 1.029}
# {'text': '시작됩니다.', 'start': 15.989, 'duration': 0.778}
# {'text': '[기대하라구♥]', 'start': 16.768, 'duration': 1.233}
# {'text': '게임이 시작됩니다.', 'start': 18.349, 'duration': 1.473}
# {'text': '[마이 넷플릭스]\n[빙고게임♥]', 'start': 19.823, 'duration': 1.393}
# {'text': '어릴 때 하던 거 말이에요?', 'start': 21.217, 'duration': 1.165}
# {'text': '[맞아요! 그 빙고!]', 'start': 22.383, 'duration': 1.587}
# {'text': '애들 게임 규칙 단순해.', 'start': 23.971, 'duration': 1.393}
# {'text': '[취향듬뿍 넷플릭스 작품으로 빙고두줄]', 'start': 25.365, 'duration': 1.811}
# {'text': '그럼 시작합니다.', 'start': 27.177, 'duration': 1.435}
# {'text': '[취향 가득 담아 써 내려가는 빙고판]', 'start': 29.157, 'duration': 1.391}
# {'text': '저는 해수 선배님이', 'start': 30.549, 'duration': 1.066}
# {'text': '[(어떤 작품)]  적으실지 알아요.', 'start': 31.616, 'duration': 1.374}
# {'text': '설마 그걸 적을까?', 'start': 32.991, 'duration': 0.995}
# {'text': '[확신] [헤헷]\n그걸 적을 것 같아요.', 'start': 33.987, 'duration': 1.604}
# {'text': '전 정재 선배님이\n뭘 적을지도 알 것 같아요.', 'start': 35.592, 'duration': 1.947}
# {'text': '[난 다 알지] [진짜?]', 'start': 37.54, 'duration': 0.847}
# {'text': "['오징어 게임'팀의 넷플릭스 취향은?]", 'start': 38.388, 'duration': 1.816}
# {'text': '[호연이 다 적었지]\n끝!', 'start': 40.205, 'duration': 0.987}
# {'text': '[넷플릭스 공부하고 왔어요♥]\n조금 공부하고 왔어요.', 'start': 41.193, 'duration': 1.167}
# {'text': '[호연 예습 칭찬해♥]\n내가 뭐 봤나.', 'start': 42.361, 'duration': 1.283}
# {'text': '[카운트다운 5, 4]', 'start': 43.645, 'duration': 1.148}
# {'text': '[다급;] [우린 다 썼지]\n[카운트다운 3, 2, 1]', 'start': 44.794, 'duration': 2.177}
# {'text': '다 못 적었는데', 'start': 46.972, 'duration': 0.826}
# {'text': '마이클 조던 나오는 거 뭐죠?', 'start': 47.799, 'duration': 1.357}
# {'text': "'마이클 조던: 더 라스트 댄스'", 'start': 49.157, 'duration': 1.437}
# {'text': '[시간이 끝나도 나는 적는다]', 'start': 50.595, 'duration': 1.458}
# {'text': '[순서 정하기]\n가위바위보!', 'start': 52.735, 'duration': 1.294}
# {'text': '[아쉽다]\n우와!', 'start': 54.03, 'duration': 1.574}
# {'text': '시작은 당연히', 'start': 55.767, 'duration': 1.604}
# {'text': "'오징어 게임'", 'start': 57.372, 'duration': 1.029}
# {'text': "['오징어 게임' 국룰이지]", 'start': 58.402, 'duration': 1.169}
# {'text': "저는 '두 교황'", 'start': 59.572, 'duration': 1.621}
# {'text': '[에휴]', 'start': 61.194, 'duration': 0.578}
# {'text': "'두 교황'을 안 적었네. ", 'start': 61.773, 'duration': 1.587}
# {'text': "'피키 블라인더스'", 'start': 63.361, 'duration': 0.839}
# {'text': '그거 쓰실 줄 알았어요. ', 'start': 65.124, 'duration': 1.45}
# {'text': '어떻게 알았지?', 'start': 66.575, 'duration': 0.832}
# {'text': "'낙원의 밤'", 'start': 67.408, 'duration': 1.15}
# {'text': '[그거 꿀잼인데] ', 'start': 68.559, 'duration': 1.053}
# {'text': "'로마'", 'start': 69.613, 'duration': 0.772}
# {'text': '-정재)로마\n-하준)로마?', 'start': 70.386, 'duration': 1.002}
# {'text': '[에휴]', 'start': 71.389, 'duration': 0.832}
# {'text': '[히히 신난당]', 'start': 72.222, 'duration': 0.802}
# {'text': "저는 '블랙핑크: 세상을 밝혀라'", 'start': 73.025, 'duration': 2.545}
# {'text': '[선배님 취향 실화예요?]\n그거 못 했어요!', 'start': 75.571, 'duration': 1.984}
# {'text': '[히히]', 'start': 77.556, 'duration': 1.439}
# {'text': '[넷플속보]\n[이정재, 블링크로 밝혀져 화제]', 'start': 78.996, 'duration': 1.588}
# {'text': "'신세계'", 'start': 80.585, 'duration': 1.014}
# {'text': '오, 있습니다. ', 'start': 81.6, 'duration': 1.395}
# {'text': '[하하]', 'start': 82.996, 'duration': 0.768}
# {'text': "[아.. '신세계'... 안 적었네...]", 'start': 83.765, 'duration': 1.182}
# {'text': '장난이 너무 심한 거 아니오!', 'start': 84.948, 'duration': 1.23}
# {'text': "'미생'", 'start': 86.179, 'duration': 0.839}
# {'text': "[오 '미생']", 'start': 87.019, 'duration': 1.121}
# {'text': '빙고 한 줄 아니죠? 두 줄?', 'start': 88.141, 'duration': 1.249}
# {'text': '한 줄이면 진작에 했지!', 'start': 89.391, 'duration': 1.256}
# {'text': '-정재)벌써?\n-하준)진짜요?', 'start': 91.759, 'duration': 1.204}
# {'text': '[헤헷]', 'start': 92.964, 'duration': 0.866}
# {'text': "'다크'", 'start': 93.831, 'duration': 0.965}
# {'text': 'Dark요?', 'start': 94.797, 'duration': 0.818}
# {'text': '독일 드라마인데', 'start': 95.616, 'duration': 1.015}
# {'text': '[다크 강추]\n진짜 재밌어요.', 'start': 96.632, 'duration': 1.174}
# {'text': "저는 '하이웨이맨'", 'start': 97.807, 'duration': 1.395}
# {'text': "'D.P.'", 'start': 99.203, 'duration': 0.99}
# {'text': "'D.P.' 있지.", 'start': 100.194, 'duration': 1.406}
# {'text': "'결혼 이야기'", 'start': 101.601, 'duration': 0.792}
# {'text': "'결혼 이야기'", 'start': 102.394, 'duration': 1.417}
# {'text': "'첨밀밀'", 'start': 103.812, 'duration': 0.986}
# {'text': '정호연 빙고!!', 'start': 104.799, 'duration': 1.749}
# {'text': '[찬란한 빙고 두 줄]', 'start': 106.549, 'duration': 0.849}
# {'text': '[아까비]', 'start': 107.399, 'duration': 1.019}
# {'text': '[호연 빙고 1등♥]', 'start': 108.419, 'duration': 1.787}
# {'text': '[정재의 넷플릭스 취향은?]\n빙고판에 쓰여져 있는 작품들이', 'start': 110.207, 'duration': 2.011}
# {'text': '두세 번 이상씩은 본 콘텐츠여서', 'start': 112.219, 'duration': 2.783}
# {'text': '[정재 취향 16개 캡처 캡처♥]\n완벽한 제 취향이라고 보셔도', 'start': 115.003, 'duration': 1.974}
# {'text': '무방할 것 같습니다.', 'start': 116.978, 'duration': 1.048}
# {'text': '[콘텐츠를 선택하는 나만의 팁은?]\n잘 고르는 팁은 없는 것 같아요.', 'start': 118.027, 'duration': 1.916}
# {'text': '일단 다 봅니다!', 'start': 119.944, 'duration': 1.409}
# {'text': '다 보고 나면\n내가 좋아하는 콘텐츠다.', 'start': 121.354, 'duration': 2.029}
# {'text': '이 작품은 남에게 추천하지 말아야지.', 'start': 123.384, 'duration': 2.42}
# {'text': '이렇게 되는 것 같아요.', 'start': 125.805, 'duration': 1.195}
# {'text': '[해수의 넷플릭스 취향은?]', 'start': 127.001, 'duration': 1.225}
# {'text': "[난 내가 취향이야♥]\n'슬기로운 감빵생활'이나", 'start': 128.227, 'duration': 1.588}
# {'text': '슬빵 명작이죠.', 'start': 131.133, 'duration': 1.426}
# {'text': "[뻔뻔] [두 번째 깨알 홍보ㅋㅋ]\n'사냥의 시간'이라는 작품을 한번", 'start': 132.56, 'duration': 1.819}
# {'text': '[해수 나오면 다 명작이죠♥]\n명작이죠.', 'start': 134.38, 'duration': 1.048}
# {'text': '안 본 소재나 이런 것들을\n좋아하는 편인 것 같아요.', 'start': 135.429, 'duration': 2.523}
# {'text': "'맨헌트'나 '나르코스'나", 'start': 137.953, 'duration': 2.043}
# {'text': '접하지 않은 시대의', 'start': 139.997, 'duration': 1.235}
# {'text': '미술 세팅도 궁금하고', 'start': 141.233, 'duration': 1.795}
# {'text': '[(미술 세팅)]\n보는 재미가 있는 것 같아서', 'start': 143.029, 'duration': 2.189}
# {'text': '[빙고를 통해 알게 되는]\n보다 보니까 그런 취향이', 'start': 145.219, 'duration': 1.581}
# {'text': '[내 넷플릭스 취향]\n제가 좀 많이 찾아보는구나.', 'start': 146.801, 'duration': 1.388}
# {'text': '이런 생각들이\n많이 들었던 것 같습니다.', 'start': 148.19, 'duration': 1.81}
# {'text': '[하준의 넷플릭스 취향은?]\n가장 좋아하는 장르가 두 가지 있는데', 'start': 150.001, 'duration': 1.597}
# {'text': '누아르랑', 'start': 151.599, 'duration': 0.789}
# {'text': '가장 현실적인     ', 'start': 152.389, 'duration': 0.989}
# {'text': '인간의 본성이나\n내면 등을 느낄 수 있는', 'start': 153.379, 'duration': 2.373}
# {'text': "'결혼 이야기'나 '미생'", 'start': 155.753, 'duration': 1.26}
# {'text': "'인간 수업'", 'start': 157.014, 'duration': 0.994}
# {'text': "'사냥의 시간', '신세계'", 'start': 158.009, 'duration': 1.77}
# {'text': "'신세계'는 군대에서", 'start': 159.78, 'duration': 1.022}
# {'text': "['신세계' 30번 정주행]\n30번 본 것 같아요.", 'start': 160.803, 'duration': 0.997}
# {'text': "[듣는 '신세계' 쑥스^^]\n진짜로", 'start': 161.801, 'duration': 1.371}
# {'text': '나도 20번은 봤지~', 'start': 163.173, 'duration': 1.437}
# {'text': '[뿌듯] [선배님♥] [존경합니다♥]\n남자라면', 'start': 164.611, 'duration': 1.96}
# {'text': '[호연의 넷플릭스 취향은?]\n저도 몰랐는데 쓴 걸 보니까', 'start': 166.572, 'duration': 1.808}
# {'text': '사람 사는 얘기를\n[(좋아하는 것 같아요)]', 'start': 168.381, 'duration': 1.838}
# {'text': '이야기의 힘이 있는', 'start': 170.22, 'duration': 1.939}
# {'text': '[맞아 맞아]\n작품들인 것 같아요.', 'start': 172.16, 'duration': 1.599}
# {'text': "'결혼 이야기'도 그렇고", 'start': 173.76, 'duration': 1.636}
# {'text': "'첨밀밀'도 그렇고", 'start': 175.397, 'duration': 1.397}
# {'text': "'내사랑'이라고 에단 호크랑", 'start': 176.795, 'duration': 2.586}
# {'text': '투박한 사랑 이야기도 너무 좋았고', 'start': 179.382, 'duration': 2.798}
# {'text': '사랑 이야기가 왜 이렇게 많죠?', 'start': 182.181, 'duration': 1.425}
# {'text': '[왜냐면 호연이가 사랑이니까♥]', 'start': 183.607, 'duration': 1.728}
# {'text': '[최애 작품 추천한다면?]\n하나만 골라야 해요?', 'start': 185.336, 'duration': 1.237}
# {'text': "'블랙핑크: 세상을 밝혀라'", 'start': 186.574, 'duration': 1.841}
# {'text': '[장꾸 정재]', 'start': 189.557, 'duration': 1.244}
# {'text': '제가 평상시에 블랙핑크', 'start': 190.802, 'duration': 1.968}
# {'text': '아주 열렬한 팬은 사실은 아니지만', 'start': 192.771, 'duration': 3.023}
# {'text': '[평소 친한 제니와 호연]\n호연 씨하고 제니 씨하고', 'start': 195.795, 'duration': 1.595}
# {'text': '[제니 안뇽]\n굉장히 친분이 두텁더라고요.', 'start': 197.391, 'duration': 2.581}
# {'text': "저희 '오징어 게임' 현장에", 'start': 199.973, 'duration': 1.658}
# {'text': '[제니+커피차=♥]\n제니 씨가 커피차와 함께 방문을 하셔서', 'start': 201.632, 'duration': 3.168}
# {'text': '저도 "우와! 블랙핑크 제니다!"', 'start': 204.801, 'duration': 2.774}
# {'text': '[정재도 신기한 제니♥]\n신기해하고', 'start': 207.576, 'duration': 1.65}
# {'text': "'블랙핑크: 세상을 밝혀라'\n예고편을 보고서", 'start': 209.227, 'duration': 1.16}
# {'text': '와, 정말 저렇게', 'start': 210.388, 'duration': 1.825}
# {'text': '치열한 경쟁 속에서\n블랙핑크가 탄생이 됐고', 'start': 212.214, 'duration': 3.18}
# {'text': '세계 1등 걸그룹이 되었구나.', 'start': 215.395, 'duration': 4.18}
# {'text': '저 정도까지 열심히 할 수 있구나.', 'start': 219.576, 'duration': 2.619}
# {'text': '[정재 그렇게 블며들어따..★]\n블랙핑크의 팬이 됐죠.', 'start': 222.196, 'duration': 1.578}
# {'text': '[블핑 강추]\n추천도 한번 해주셨어요.', 'start': 223.775, 'duration': 1.431}
# {'text': '[같이 블링크가 됐어요♥]\n저도 그래서 같이 보고', 'start': 225.207, 'duration': 2.016}
# {'text': '[다큐멘터리 추천해 주세요]\n이건 정말 좋은 다큐멘터리라고', 'start': 227.224, 'duration': 2.922}
# {'text': '얘기할 수 있는 것들이\n몇 가지가 있는데', 'start': 230.147, 'duration': 2.082}
# {'text': "'고양이는 건드리지 마라: 인터넷 킬러 사냥'", 'start': 232.23, 'duration': 1.526}
# {'text': '굉장히 흡입력 있게', 'start': 233.757, 'duration': 1.605}
# {'text': '구성을 잘하신 것 같아요.', 'start': 235.363, 'duration': 1.239}
# {'text': '기사로써 읽었을 때의', 'start': 236.603, 'duration': 2.159}
# {'text': '충격감보다 훨씬 더', 'start': 238.763, 'duration': 1.828}
# {'text': '충격적인 구성으로 되어 있지 않나\n그렇게 봅니다.', 'start': 240.592, 'duration': 3.228}
# {'text': "'마이클 조던: 더 라스트 댄스'", 'start': 243.821, 'duration': 2.604}
# {'text': '보면서도 굉장히', 'start': 246.426, 'duration': 1.158}
# {'text': '와 이거를 어떻게 이 긴 시간과', 'start': 247.585, 'duration': 2.608}
# {'text': '여러 감정들을 느끼게 할 수 있는', 'start': 250.194, 'duration': 2.38}
# {'text': '이야기들을 잘 편집해서', 'start': 252.575, 'duration': 1.99}
# {'text': '잘 만들었을까', 'start': 254.566, 'duration': 1.15}
# {'text': '[정재 추천]\n굉장히 놀라운 작품들이라고 생각해요.', 'start': 255.717, 'duration': 1.867}
# {'text': '제가 진짜 추천하고 싶은 다큐멘터리는', 'start': 257.585, 'duration': 2.585}
# {'text': "'헤드스페이스: 숙면이 필요할 때'라는", 'start': 260.171, 'duration': 3.179}
# {'text': '[그거 좋지]\n작품이 있어요.', 'start': 263.351, 'duration': 1.024}
# {'text': '잠이 안 오고 이럴 때', 'start': 264.376, 'duration': 1.404}
# {'text': '이완 명상도 같이\n따라 해 보고 하다 보면', 'start': 265.781, 'duration': 3.175}
# {'text': '어느 순간에 잠이 들더라고요.', 'start': 268.957, 'duration': 1.866}
# {'text': '그래서 그것도 너무 유용해요!', 'start': 270.824, 'duration': 1.999}
# {'text': '그래서 추천하고 싶습니다.', 'start': 272.824, 'duration': 1.978}
# {'text': "'익스플레인: 세계를 해설하다'는", 'start': 274.803, 'duration': 1.404}
# {'text': '짧은 형식의 다큐멘터리이거든요?', 'start': 276.208, 'duration': 2.784}
# {'text': '주제가 되게 다양해요.', 'start': 278.993, 'duration': 1.632}
# {'text': '소리, 피부, 주식 시장', 'start': 280.626, 'duration': 2.553}
# {'text': '질문을 던져주는\n다큐멘터리인 것 같더라고요.', 'start': 283.18, 'duration': 3.627}
# {'text': '평소에는 한 번도\n고민해 보지 못했던 것들을', 'start': 286.808, 'duration': 3.165}
# {'text': '한 번쯤은 고민하게 되고', 'start': 289.974, 'duration': 1.823}
# {'text': '궁금한 게 있으면 더 찾아보고', 'start': 291.798, 'duration': 1.756}
# {'text': '친구들과 얘기하게 될 수 있어서', 'start': 293.555, 'duration': 1.842}
# {'text': '좋은 영감이 되는 다큐멘터리예요.', 'start': 295.398, 'duration': 2.367}
# {'text': "[추천하고 싶은 작품은?]\n저는 '피키 블라인더스'", 'start': 297.766, 'duration': 1.822}
# {'text': '[그거일 줄 알았죠]\n라는 영화가 있는데', 'start': 299.589, 'duration': 1.985}
# {'text': '1차 세계대전 이후에', 'start': 301.575, 'duration': 2.204}
# {'text': '셀비 가족이라는 가족들이', 'start': 303.78, 'duration': 1.773}
# {'text': '마권을 가지고 있던 가족들이', 'start': 305.554, 'duration': 2.016}
# {'text': '어느 순간 정치계 쪽까지 가는', 'start': 307.571, 'duration': 2.671}
# {'text': '권력을 잡는 그런 이야기인데', 'start': 310.243, 'duration': 1.972}
# {'text': '작품이 가지고 있는 색깔, 시대 배경', 'start': 312.216, 'duration': 2.341}
# {'text': '캐릭터들이 가지고 있는 트라우마', 'start': 314.558, 'duration': 1.574}
# {'text': '트라우마들을 녹여내면서 연기하는 그', 'start': 316.133, 'duration': 2.468}
# {'text': '캐릭터 표현력들이 굉장히 좋아서', 'start': 318.602, 'duration': 2.002}
# {'text': '의상이나 그 시대가 가지고 있는 배경', 'start': 320.605, 'duration': 2.596}
# {'text': '미술 세팅 이런 것들이\n너무 아름다웠던 것 같아요.', 'start': 323.202, 'duration': 2.827}
# {'text': '저한테는 배울 게 많아서', 'start': 326.03, 'duration': 1.397}
# {'text': '굉장히 애착하는 작품입니다.', 'start': 327.428, 'duration': 1.549}
# {'text': '왜냐면 현장에서도', 'start': 328.978, 'duration': 1.606}
# {'text': "'피키 블라인더스' 추천을\n많이 하셨고", 'start': 330.585, 'duration': 1.571}
# {'text': '킬리언 머피를', 'start': 332.157, 'duration': 1.464}
# {'text': '[완전 좋아하지]\n굉장히 좋아하신다고 얘기를 들어서', 'start': 333.622, 'duration': 2.776}
# {'text': '저도 빠지게 됐습니다.', 'start': 336.399, 'duration': 1.422}
# {'text': "['피키 블라인더스' 꼭 봐야지 메모]", 'start': 337.822, 'duration': 1.342}
# {'text': '[오늘 집 가서 봐야지♥]', 'start': 339.165, 'duration': 1.057}
# {'text': '[최애 작품은?]\n최애...', 'start': 340.357, 'duration': 1.432}
# {'text': '[다 좋은데 어쩌지]\n다 너무 좋아하는데', 'start': 341.79, 'duration': 1.58}
# {'text': "근래 'D.P.'를 봤거든요.", 'start': 343.371, 'duration': 1.389}
# {'text': "['D.P.' 띵작이지]\n최근에", 'start': 344.761, 'duration': 1.204}
# {'text': '[(저도)] 군대를 다녀온 입장이고', 'start': 345.966, 'duration': 1.976}
# {'text': '저는 D.P.는 아니었지만', 'start': 347.943, 'duration': 1.224}
# {'text': '[헌병대 출신 하준]\n헌병대 출신이어서', 'start': 349.168, 'duration': 1.599}
# {'text': '제가 군대에 있을 때는', 'start': 350.768, 'duration': 1.81}
# {'text': '[(영화만큼의)]\n부조리, 가혹 행위는 아니었지만', 'start': 352.579, 'duration': 2.023}
# {'text': '선배님들은 분명히\n그런 현실을 겪었단 말이죠.', 'start': 354.603, 'duration': 3.556}
# {'text': '안타까움, 화도 많이 났었고', 'start': 358.16, 'duration': 2.456}
# {'text': '탈영병들을 잡으면서', 'start': 360.617, 'duration': 2.008}
# {'text': '그들이 왜 탈영을 하게 됐는지', 'start': 362.626, 'duration': 1.534}
# {'text': '공감도 많이 됐었고', 'start': 364.161, 'duration': 1.225}
# {'text': '치유되기도 하고', 'start': 365.387, 'duration': 0.988}
# {'text': '특히 조현철 선배의 연기가\n[(좋았어요)]', 'start': 366.376, 'duration': 1.194}
# {'text': "제 데뷔작이 '차이나타운'인데", 'start': 367.571, 'duration': 1.615}
# {'text': '[(조현철 배우가)]\n홍주라는 역할을 하셨었는데', 'start': 369.187, 'duration': 2.598}
# {'text': '그때부터 너무 인상 깊게 봤었는데', 'start': 371.786, 'duration': 1.808}
# {'text': "'D.P.'에서 또한", 'start': 373.595, 'duration': 1.18}
# {'text': '오타쿠인 일병으로 나오다가', 'start': 374.776, 'duration': 1.807}
# {'text': '감정의 폭발력이\n굉장히 세게 오더라고요.', 'start': 376.584, 'duration': 3.393}
# {'text': '인상 깊었습니다.', 'start': 379.978, 'duration': 1.249}
# {'text': "['종이의 집'을 좋아하신다고?]\n'종이의 집'은 넷플릭스 회원이라면", 'start': 381.555, 'duration': 2.239}
# {'text': "[넷플릭스 레전드] [모두가 좋아하는 '종이의 집']\n다 보셨고, 다 좋아하실 것 같은데", 'start': 383.795, 'duration': 1.975}
# {'text': "어떻게 보면 '종이의 집'으로 인해서", 'start': 385.771, 'duration': 1.426}
# {'text': '넷플릭스를 접했고, 빠지게 됐고', 'start': 387.198, 'duration': 2.804}
# {'text': '[촬영일 기준 공개 전]\n시즌 5도 나온다고 해서', 'start': 390.003, 'duration': 1.383}
# {'text': "['종이의 집' 시즌 5 잘 보고 계시죠?]\n되게 기대하고 있습니다.", 'start': 391.387, 'duration': 1.169}
# {'text': "[한국판 '종이의 집' 베를린 역할을 맡으셨는데?]", 'start': 392.557, 'duration': 1.236}
# {'text': '[부끄 부끄]\n너무 기대돼.', 'start': 393.794, 'duration': 1.217}
# {'text': "사실 저는 '종이의 집'\n엄청 팬이었고", 'start': 395.012, 'duration': 1.956}
# {'text': '베를린 역할은 굉장히\n부담스러운 역할이었죠. 저한테는', 'start': 396.969, 'duration': 2.858}
# {'text': "[(원작)] '종이의 집'의 베를린은\n조금 냉철하고", 'start': 399.828, 'duration': 2.779}
# {'text': '냉혈하고 어떤 면에서는', 'start': 402.608, 'duration': 2.384}
# {'text': '악으로 치닫는 경계선에 있는 사람인데', 'start': 404.993, 'duration': 2.212}
# {'text': '[(한국판)] 베를린은', 'start': 407.206, 'duration': 2.752}
# {'text': '깊은 이유가 있는 역할로 나와서', 'start': 409.959, 'duration': 2.427}
# {'text': '전혀 다른 캐릭터가 표현될 것 같고', 'start': 412.387, 'duration': 2.593}
# {'text': "'베를린'이라는\n한 인간을 정확히 표현하자.", 'start': 414.981, 'duration': 2.236}
# {'text': '[(라는 생각으로)] 준비하고 있어서', 'start': 417.218, 'duration': 1.612}
# {'text': '[해수의 베를린도 기대해 주세요♥]\n아마 캐릭터가 굉장히 상반될 거에요.', 'start': 418.831, 'duration': 1.976}
# {'text': '제 최애 작품은', 'start': 420.808, 'duration': 1.585}
# {'text': "여기서 뽑자면 '로마'", 'start': 422.394, 'duration': 2.369}
# {'text': "'로마'를 봤을 때가 '오징어 게임'", 'start': 424.764, 'duration': 2.249}
# {'text': '캐스팅 이후였던 것 같은데', 'start': 427.014, 'duration': 2.546}
# {'text': "'로마'에 나오는 여자 주인공도\n연기가 처음인", 'start': 429.561, 'duration': 3.025}
# {'text': '그녀의 연기를 보면서\n위로받았던 것 같아요.', 'start': 432.587, 'duration': 3.604}
# {'text': '뭔가 연기적으로 조금 힘들거나', 'start': 436.192, 'duration': 2.387}
# {'text': '고민이 많은 시점에 보면', 'start': 438.58, 'duration': 2.041}
# {'text': '리프레시 되는 작품이지 않나라는\n생각이 들어서', 'start': 440.622, 'duration': 2.584}
# {'text': "[호연 PICK '로마']\n추천하고 싶습니다.", 'start': 443.207, 'duration': 2.408}
# {'text': '장르물을 선배님들이\n다 좋아하시는 것 같아서', 'start': 445.761, 'duration': 3.816}
# {'text': "'다크'라는 작품이 있는데", 'start': 449.578, 'duration': 2.799}
# {'text': '되게 소재도 신선하고', 'start': 452.378, 'duration': 1.829}
# {'text': '작은 아이의 실종 사건으로\n시작이 되는데', 'start': 454.208, 'duration': 3.97}
# {'text': '[해수는 스포 시져]', 'start': 458.179, 'duration': 1.846}
# {'text': '스포 아니에요.', 'start': 460.748, 'duration': 1.25}
# {'text': '[다행]\n아니야?', 'start': 461.999, 'duration': 1.007}
# {'text': '서로에게 숨겼던 비밀들이', 'start': 463.007, 'duration': 2.355}
# {'text': '점점 폭발하면서\n계속 전개가 되거든요.', 'start': 465.363, 'duration': 3.014}
# {'text': '이 마을 전체가\n파괴되는 지경까지 가서', 'start': 468.378, 'duration': 4.002}
# {'text': '엄청 흥미롭고\n끊을 수가 없습니다.', 'start': 472.381, 'duration': 2.596}
# {'text': '-정재)다크\n-해수)다크     ', 'start': 474.977, 'duration': 1.404}
# {'text': "['다크' 정재 마음에 저장♥]", 'start': 476.382, 'duration': 1.219}
# {'text': "[아직도 '다크' 찾는 중]\n저는 진짜 얼마 전에 안 건데", 'start': 477.602, 'duration': 1.377}
# {'text': '넷플릭스에 모닥불', 'start': 478.98, 'duration': 1.218}
# {'text': '그게 뭐예요?', 'start': 480.199, 'duration': 0.777}
# {'text': '[(넷플릭스에)] 모닥불을 치면', 'start': 480.977, 'duration': 1.384}
# {'text': '모닥불이 타면서 모닥불이 나와요.', 'start': 482.362, 'duration': 1.617}
# {'text': '[꿀팁]', 'start': 483.98, 'duration': 1.217}
# {'text': '-하준)그냥 나와요 불이?\n-해수)나와요.', 'start': 485.198, 'duration': 1.426}
# {'text': '혼술 할 때 아주 예술', 'start': 486.625, 'duration': 1.381}
# {'text': "['오징어 게임'을 한마디로?]\n이 정도 게임이면", 'start': 488.322, 'duration': 2.08}
# {'text': '굉장히 유혹적이죠.', 'start': 490.403, 'duration': 1.534}
# {'text': '선배님 목소리 들으니까', 'start': 491.938, 'duration': 1.06}
# {'text': '[심장 정재 올 뻔♥]\n가슴이 약간 뛰었어요.', 'start': 492.999, 'duration': 1.223}
# {'text': '제가 굉장히 유혹적이죠.', 'start': 495.55, 'duration': 1.435}
# {'text': '저희 작품은 드라마의 힘!', 'start': 496.986, 'duration': 2.17}
# {'text': '빼놓을 수 없을 것 같습니다.', 'start': 499.157, 'duration': 1.247}
# {'text': '사랑스럽고 아기자기한 공간에 상반되는', 'start': 500.405, 'duration': 4.349}
# {'text': '인물들의 삶!', 'start': 504.755, 'duration': 2.041}
# {'text': '회가 거듭할수록 드러나는', 'start': 506.797, 'duration': 1.756}
# {'text': '반전의 힘!', 'start': 508.554, 'duration': 0.869}
# {'text': '저는 굉장히 크다고 생각합니다.', 'start': 509.424, 'duration': 1.754}
# {'text': '네 분의 영화 취향이 다양한 것처럼', 'start': 511.179, 'duration': 3.036}
# {'text': "'오징어 게임'도", 'start': 514.216, 'duration': 1.196}
# {'text': '다양한 장르물과 다양한 이야기와', 'start': 515.413, 'duration': 2.576}
# {'text': '다양한 요소들이 많이 담겨있는\n그런 작품인 것 같습니다. ', 'start': 517.99, 'duration': 3.784}
# {'text': "'오징어 게임'\n많은 기대 부탁드립니다.", 'start': 521.775, 'duration': 1.253}
# {'text': '넷플릭스에서 만나요♥', 'start': 523.029, 'duration': 2.182}
# {'text': '[구독하기]', 'start': 533.131, 'duration': 10.315}

# %%
text = ''
 
for i in range(len(srt)):
    text += srt[i]['text'] + ' ' # text 부분만 가져옴
    
text_ = text.replace(' ','')

# %%
text_
# Out:
# '저는...\'블랙핑크:세상을밝혀라\'[정재취향궁금하면드루와]\n그거못했어요![마이_넷플릭스]안녕하세요!\'오징어게임\'의이정재박해수위하준정호연입니다.지금부터\'오징어게임\'팀의취향을가득담은\'마이넷플릭스\'가시작됩니다.[기대하라구♥]게임이시작됩니다.[마이넷플릭스]\n[빙고게임♥]어릴때하던거말이에요?[맞아요!그빙고!]애들게임규칙단순해.[취향듬뿍넷플릭스작품으로빙고두줄]그럼시작합니다.[취향가득담아써내려가는빙고판]저는해수선배님이[(어떤작품)]적으실지알아요.설마그걸적을까?[확신][헤헷]\n그걸적을것같아요.전정재선배님이\n뭘적을지도알것같아요.[난다알지][진짜?][\'오징어게임\'팀의넷플릭스취향은?][호연이다적었지]\n끝![넷플릭스공부하고왔어요♥]\n조금공부하고왔어요.[호연예습칭찬해♥]\n내가뭐봤나.[카운트다운5,4][다급;][우린다썼지]\n[카운트다운3,2,1]다못적었는데마이클조던나오는거뭐죠?\'마이클조던:더라스트댄스\'[시간이끝나도나는적는다][순서정하기]\n가위바위보![아쉽다]\n우와!시작은당연히\'오징어게임\'[\'오징어게임\'국룰이지]저는\'두교황\'[에휴]\'두교황\'을안적었네.\'피키블라인더스\'그거쓰실줄알았어요.어떻게알았지?\'낙원의밤\'[그거꿀잼인데]\'로마\'-정재)로마\n-하준)로마?[에휴][히히신난당]저는\'블랙핑크:세상을밝혀라\'[선배님취향실화예요?]\n그거못했어요![히히][넷플속보]\n[이정재,블링크로밝혀져화제]\'신세계\'오,있습니다.[하하][아..\'신세계\'...안적었네...]장난이너무심한거아니오!\'미생\'[오\'미생\']빙고한줄아니죠?두줄?한줄이면진작에했지!-정재)벌써?\n-하준)진짜요?[헤헷]\'다크\'Dark요?독일드라마인데[다크강추]\n진짜재밌어요.저는\'하이웨이맨\'\'D.P.\'\'D.P.\'있지.\'결혼이야기\'\'결혼이야기\'\'첨밀밀\'정호연빙고!![찬란한빙고두줄][아까비][호연빙고1등♥][정재의넷플릭스취향은?]\n빙고판에쓰여져있는작품들이두세번이상씩은본콘텐츠여서[정재취향16개캡처캡처♥]\n완벽한제취향이라고보셔도무방할것같습니다.[콘텐츠를선택하는나만의팁은?]\n잘고르는팁은없는것같아요.일단다봅니다!다보고나면\n내가좋아하는콘텐츠다.이작품은남에게추천하지말아야지.이렇게되는것같아요.[해수의넷플릭스취향은?][난내가취향이야♥]\n\'슬기로운감빵생활\'이나슬빵명작이죠.[뻔뻔][두번째깨알홍보ㅋㅋ]\n\'사냥의시간\'이라는작품을한번[해수나오면다명작이죠♥]\n명작이죠.안본소재나이런것들을\n좋아하는편인것같아요.\'맨헌트\'나\'나르코스\'나접하지않은시대의미술세팅도궁금하고[(미술세팅)]\n보는재미가있는것같아서[빙고를통해알게되는]\n보다보니까그런취향이[내넷플릭스취향]\n제가좀많이찾아보는구나.이런생각들이\n많이들었던것같습니다.[하준의넷플릭스취향은?]\n가장좋아하는장르가두가지있는데누아르랑가장현실적인인간의본성이나\n내면등을느낄수있는\'결혼이야기\'나\'미생\'\'인간수업\'\'사냥의시간\',\'신세계\'\'신세계\'는군대에서[\'신세계\'30번정주행]\n30번본것같아요.[듣는\'신세계\'쑥스^^]\n진짜로나도20번은봤지~[뿌듯][선배님♥][존경합니다♥]\n남자라면[호연의넷플릭스취향은?]\n저도몰랐는데쓴걸보니까사람사는얘기를\n[(좋아하는것같아요)]이야기의힘이있는[맞아맞아]\n작품들인것같아요.\'결혼이야기\'도그렇고\'첨밀밀\'도그렇고\'내사랑\'이라고에단호크랑투박한사랑이야기도너무좋았고사랑이야기가왜이렇게많죠?[왜냐면호연이가사랑이니까♥][최애작품추천한다면?]\n하나만골라야해요?\'블랙핑크:세상을밝혀라\'[장꾸정재]제가평상시에블랙핑크아주열렬한팬은사실은아니지만[평소친한제니와호연]\n호연씨하고제니씨하고[제니안뇽]\n굉장히친분이두텁더라고요.저희\'오징어게임\'현장에[제니+커피차=♥]\n제니씨가커피차와함께방문을하셔서저도"우와!블랙핑크제니다!"[정재도신기한제니♥]\n신기해하고\'블랙핑크:세상을밝혀라\'\n예고편을보고서와,정말저렇게치열한경쟁속에서\n블랙핑크가탄생이됐고세계1등걸그룹이되었구나.저정도까지열심히할수있구나.[정재그렇게블며들어따..★]\n블랙핑크의팬이됐죠.[블핑강추]\n추천도한번해주셨어요.[같이블링크가됐어요♥]\n저도그래서같이보고[다큐멘터리추천해주세요]\n이건정말좋은다큐멘터리라고얘기할수있는것들이\n몇가지가있는데\'고양이는건드리지마라:인터넷킬러사냥\'굉장히흡입력있게구성을잘하신것같아요.기사로써읽었을때의충격감보다훨씬더충격적인구성으로되어있지않나\n그렇게봅니다.\'마이클조던:더라스트댄스\'보면서도굉장히와이거를어떻게이긴시간과여러감정들을느끼게할수있는이야기들을잘편집해서잘만들었을까[정재추천]\n굉장히놀라운작품들이라고생각해요.제가진짜추천하고싶은다큐멘터리는\'헤드스페이스:숙면이필요할때\'라는[그거좋지]\n작품이있어요.잠이안오고이럴때이완명상도같이\n따라해보고하다보면어느순간에잠이들더라고요.그래서그것도너무유용해요!그래서추천하고싶습니다.\'익스플레인:세계를해설하다\'는짧은형식의다큐멘터리이거든요?주제가되게다양해요.소리,피부,주식시장질문을던져주는\n다큐멘터리인것같더라고요.평소에는한번도\n고민해보지못했던것들을한번쯤은고민하게되고궁금한게있으면더찾아보고친구들과얘기하게될수있어서좋은영감이되는다큐멘터리예요.[추천하고싶은작품은?]\n저는\'피키블라인더스\'[그거일줄알았죠]\n라는영화가있는데1차세계대전이후에셀비가족이라는가족들이마권을가지고있던가족들이어느순간정치계쪽까지가는권력을잡는그런이야기인데작품이가지고있는색깔,시대배경캐릭터들이가지고있는트라우마트라우마들을녹여내면서연기하는그캐릭터표현력들이굉장히좋아서의상이나그시대가가지고있는배경미술세팅이런것들이\n너무아름다웠던것같아요.저한테는배울게많아서굉장히애착하는작품입니다.왜냐면현장에서도\'피키블라인더스\'추천을\n많이하셨고킬리언머피를[완전좋아하지]\n굉장히좋아하신다고얘기를들어서저도빠지게됐습니다.[\'피키블라인더스\'꼭봐야지메모][오늘집가서봐야지♥][최애작품은?]\n최애...[다좋은데어쩌지]\n다너무좋아하는데근래\'D.P.\'를봤거든요.[\'D.P.\'띵작이지]\n최근에[(저도)]군대를다녀온입장이고저는D.P.는아니었지만[헌병대출신하준]\n헌병대출신이어서제가군대에있을때는[(영화만큼의)]\n부조리,가혹행위는아니었지만선배님들은분명히\n그런현실을겪었단말이죠.안타까움,화도많이났었고탈영병들을잡으면서그들이왜탈영을하게됐는지공감도많이됐었고치유되기도하고특히조현철선배의연기가\n[(좋았어요)]제데뷔작이\'차이나타운\'인데[(조현철배우가)]\n홍주라는역할을하셨었는데그때부터너무인상깊게봤었는데\'D.P.\'에서또한오타쿠인일병으로나오다가감정의폭발력이\n굉장히세게오더라고요.인상깊었습니다.[\'종이의집\'을좋아하신다고?]\n\'종이의집\'은넷플릭스회원이라면[넷플릭스레전드][모두가좋아하는\'종이의집\']\n다보셨고,다좋아하실것같은데어떻게보면\'종이의집\'으로인해서넷플릭스를접했고,빠지게됐고[촬영일기준공개전]\n시즌5도나온다고해서[\'종이의집\'시즌5잘보고계시죠?]\n되게기대하고있습니다.[한국판\'종이의집\'베를린역할을맡으셨는데?][부끄부끄]\n너무기대돼.사실저는\'종이의집\'\n엄청팬이었고베를린역할은굉장히\n부담스러운역할이었죠.저한테는[(원작)]\'종이의집\'의베를린은\n조금냉철하고냉혈하고어떤면에서는악으로치닫는경계선에있는사람인데[(한국판)]베를린은깊은이유가있는역할로나와서전혀다른캐릭터가표현될것같고\'베를린\'이라는\n한인간을정확히표현하자.[(라는생각으로)]준비하고있어서[해수의베를린도기대해주세요♥]\n아마캐릭터가굉장히상반될거에요.제최애작품은여기서뽑자면\'로마\'\'로마\'를봤을때가\'오징어게임\'캐스팅이후였던것같은데\'로마\'에나오는여자주인공도\n연기가처음인그녀의연기를보면서\n위로받았던것같아요.뭔가연기적으로조금힘들거나고민이많은시점에보면리프레시되는작품이지않나라는\n생각이들어서[호연PICK\'로마\']\n추천하고싶습니다.장르물을선배님들이\n다좋아하시는것같아서\'다크\'라는작품이있는데되게소재도신선하고작은아이의실종사건으로\n시작이되는데[해수는스포시져]스포아니에요.[다행]\n아니야?서로에게숨겼던비밀들이점점폭발하면서\n계속전개가되거든요.이마을전체가\n파괴되는지경까지가서엄청흥미롭고\n끊을수가없습니다.-정재)다크\n-해수)다크[\'다크\'정재마음에저장♥][아직도\'다크\'찾는중]\n저는진짜얼마전에안건데넷플릭스에모닥불그게뭐예요?[(넷플릭스에)]모닥불을치면모닥불이타면서모닥불이나와요.[꿀팁]-하준)그냥나와요불이 ...

# %%
texts = list()
 
for i in range(len(srt)):
  texts.append(srt[i]['text']) 

texts
# Out:
# ['저는...',
#  "'블랙핑크: 세상을 밝혀라'  ",
#  '[정재 취향 궁금하면 드루와]\n그거 못 했어요!',
#  '[마이_넷플릭스]',
#  '안녕하세요!',
#  "'오징어 게임'의 이정재",
#  '박해수',
#  '위하준',
#  '정호연입니다.',
#  "지금부터 '오징어 게임' 팀의",
#  '취향을 가득 담은',
#  "'마이 넷플릭스'가",
#  '시작됩니다.',
#  '[기대하라구♥]',
#  '게임이 시작됩니다.',
#  '[마이 넷플릭스]\n[빙고게임♥]',
#  '어릴 때 하던 거 말이에요?',
#  '[맞아요! 그 빙고!]',
#  '애들 게임 규칙 단순해.',
#  '[취향듬뿍 넷플릭스 작품으로 빙고두줄]',
#  '그럼 시작합니다.',
#  '[취향 가득 담아 써 내려가는 빙고판]',
#  '저는 해수 선배님이',
#  '[(어떤 작품)]  적으실지 알아요.',
#  '설마 그걸 적을까?',
#  '[확신] [헤헷]\n그걸 적을 것 같아요.',
#  '전 정재 선배님이\n뭘 적을지도 알 것 같아요.',
#  '[난 다 알지] [진짜?]',
#  "['오징어 게임'팀의 넷플릭스 취향은?]",
#  '[호연이 다 적었지]\n끝!',
#  '[넷플릭스 공부하고 왔어요♥]\n조금 공부하고 왔어요.',
#  '[호연 예습 칭찬해♥]\n내가 뭐 봤나.',
#  '[카운트다운 5, 4]',
#  '[다급;] [우린 다 썼지]\n[카운트다운 3, 2, 1]',
#  '다 못 적었는데',
#  '마이클 조던 나오는 거 뭐죠?',
#  "'마이클 조던: 더 라스트 댄스'",
#  '[시간이 끝나도 나는 적는다]',
#  '[순서 정하기]\n가위바위보!',
#  '[아쉽다]\n우와!',
#  '시작은 당연히',
#  "'오징어 게임'",
#  "['오징어 게임' 국룰이지]",
#  "저는 '두 교황'",
#  '[에휴]',
#  "'두 교황'을 안 적었네. ",
#  "'피키 블라인더스'",
#  '그거 쓰실 줄 알았어요. ',
#  '어떻게 알았지?',
#  "'낙원의 밤'",
#  '[그거 꿀잼인데] ',
#  "'로마'",
#  '-정재)로마\n-하준)로마?',
#  '[에휴]',
#  '[히히 신난당]',
#  "저는 '블랙핑크: 세상을 밝혀라'",
#  '[선배님 취향 실화예요?]\n그거 못 했어요!',
#  '[히히]',
#  '[넷플속보]\n[이정재, 블링크로 밝혀져 화제]',
#  "'신세계'",
#  '오, 있습니다. ',
#  '[하하]',
#  "[아.. '신세계'... 안 적었네...]",
#  '장난이 너무 심한 거 아니오!',
#  "'미생'",
#  "[오 '미생']",
#  '빙고 한 줄 아니죠? 두 줄?',
#  '한 줄이면 진작에 했지!',
#  '-정재)벌써?\n-하준)진짜요?',
#  '[헤헷]',
#  "'다크'",
#  'Dark요?',
#  '독일 드라마인데',
#  '[다크 강추]\n진짜 재밌어요.',
#  "저는 '하이웨이맨'",
#  "'D.P.'",
#  "'D.P.' 있지.",
#  "'결혼 이야기'",
#  "'결혼 이야기'",
#  "'첨밀밀'",
#  '정호연 빙고!!',
#  '[찬란한 빙고 두 줄]',
#  '[아까비]',
#  '[호연 빙고 1등♥]',
#  '[정재의 넷플릭스 취향은?]\n빙고판에 쓰여져 있는 작품들이',
#  '두세 번 이상씩은 본 콘텐츠여서',
#  '[정재 취향 16개 캡처 캡처♥]\n완벽한 제 취향이라고 보셔도',
#  '무방할 것 같습니다.',
#  '[콘텐츠를 선택하는 나만의 팁은?]\n잘 고르는 팁은 없는 것 같아요.',
#  '일단 다 봅니다!',
#  '다 보고 나면\n내가 좋아하는 콘텐츠다.',
#  '이 작품은 남에게 추천하지 말아야지.',
#  '이렇게 되는 것 같아요.',
#  '[해수의 넷플릭스 취향은?]',
#  "[난 내가 취향이야♥]\n'슬기로운 감빵생활'이나",
#  '슬빵 명작이죠.',
#  "[뻔뻔] [두 번째 깨알 홍보ㅋㅋ]\n'사냥의 시간'이라는 작품을 한번",
#  '[해수 나오면 다 명작이죠♥]\n명작이죠.',
#  '안 본 소재나 이런 것들을\n좋아하는 편인 것 같아요.',
#  "'맨헌트'나 '나르코스'나",
#  '접하지 않은 시대의',
#  '미술 세팅도 궁금하고',
#  '[(미술 세팅)]\n보는 재미가 있는 것 같아서',
#  '[빙고를 통해 알게 되는]\n보다 보니까 그런 취향이',
#  '[내 넷플릭스 취향]\n제가 좀 많이 찾아보는구나.',
#  '이런 생각들이\n많이 들었던 것 같습니다.',
#  '[하준의 넷플릭스 취향은?]\n가장 좋아하는 장르가 두 가지 있는데',
#  '누아르랑',
#  '가장 현실적인     ',
#  '인간의 본성이나\n내면 등을 느낄 수 있는',
#  "'결혼 이야기'나 '미생'",
#  "'인간 수업'",
#  "'사냥의 시간', '신세계'",
#  "'신세계'는 군대에서",
#  "['신세계' 30번 정주행]\n30번 본 것 같아요.",
#  "[듣는 '신세계' 쑥스^^]\n진짜로",
#  '나도 20번은 봤지~',
#  '[뿌듯] [선배님♥] [존경합니다♥]\n남자라면',
#  '[호연의 넷플릭스 취향은?]\n저도 몰랐는데 쓴 걸 보니까',
#  '사람 사는 얘기를\n[(좋아하는 것 같아요)]',
#  '이야기의 힘이 있는',
#  '[맞아 맞아]\n작품들인 것 같아요.',
#  "'결혼 이야기'도 그렇고",
#  "'첨밀밀'도 그렇고",
#  "'내사랑'이라고 에단 호크랑",
#  '투박한 사랑 이야기도 너무 좋았고',
#  '사랑 이야기가 왜 이렇게 많죠?',
#  '[왜냐면 호연이가 사랑이니까♥]',
#  '[최애 작품 추천한다면?]\n하나만 골라야 해요?',
#  "'블랙핑크: 세상을 밝혀라'",
#  '[장꾸 정재]',
#  '제가 평상시에 블랙핑크',
#  '아주 열렬한 팬은 사실은 아니지만',
#  '[평소 친한 제니와 호연]\n호연 씨하고 제니 씨하고',
#  '[제니 안뇽]\n굉장히 친분이 두텁더라고요.',
#  "저희 '오징어 게임' 현장에",
#  '[제니+커피차=♥]\n제니 씨가 커피차와 함께 방문을 하셔서',
#  '저도 "우와! 블랙핑크 제니다!"',
#  '[정재도 신기한 제니♥]\n신기해하고',
#  "'블랙핑크: 세상을 밝혀라'\n예고편을 보고서",
#  '와, 정말 저렇게',
#  '치열한 경쟁 속에서\n블랙핑크가 탄생이 됐고',
#  '세계 1등 걸그룹이 되었구나.',
#  '저 정도까지 열심히 할 수 있구나.',
#  '[정재 그렇게 블며들어따..★]\n블랙핑크의 팬이 됐죠.',
#  '[블핑 강추]\n추천도 한번 해주셨어요.',
#  '[같이 블링크가 됐어요♥]\n저도 그래서 같이 보고',
#  '[다큐멘터리 추천해 주세요]\n이건 정말 좋은 다큐멘터리라고',
#  '얘기할 수 있는 것들이\n몇 가지가 있는데',
#  "'고양이는 건드리지 마라: 인터넷 킬러 사냥'",
#  '굉장히 흡입력 있게',
#  '구성을 잘하신 것 같아요.',
#  '기사로써 읽었을 때의',
#  '충격감보다 훨씬 더',
#  '충격적인 구성으로 되어 있지 않나\n그렇게 봅니다.',
#  "'마이클 조던: 더 라스트 댄스'",
#  '보면서도 굉장히',
#  '와 이거를 어떻게 이 긴 시간과',
#  '여러 감정들을 느끼게 할 수 있는',
#  '이야기들을 잘 편집해서',
#  '잘 만들었을까',
#  '[정재 추천]\n굉장히 놀라운 작품들이라고 생각해요.',
#  '제가 진짜 추천하고 싶은 다큐멘터리는',
#  "'헤드스페이스: 숙면이 필요할 때'라는",
#  '[그거 좋지]\n작품이 있어요.',
#  '잠이 안 오고 이럴 때',
#  '이완 명상도 같이\n따라 해 보고 하다 보면',
#  '어느 순간에 잠이 들더라고요.',
#  '그래서 그것도 너무 유용해요!',
#  '그래서 추천하고 싶습니다.',
#  "'익스플레인: 세계를 해설하다'는",
#  '짧은 형식의 다큐멘터리이거든요?',
#  '주제가 되게 다양해요.',
#  '소리, 피부, 주식 시장',
#  '질문을 던져주는\n다큐멘터리인 것 같더라고요.',
#  '평소에는 한 번도\n고민해 보지 못했던 것들을',
#  '한 번쯤은 고민하게 되고',
#  '궁금한 게 있으면 더 찾아보고',
#  '친구들과 얘기하게 될 수 있어서',
#  '좋은 영감이 되는 다큐멘터리예요.',
#  "[추천하고 싶은 작품은?]\n저는 '피키 블라인더스'",
#  '[그거일 줄 알았죠]\n라는 영화가 있는데',
#  '1차 세계대전 이후에',
#  '셀비 가족이라는 가족들이',
#  '마권을 가지고 있던 가족들이',
#  '어느 순간 정치계 쪽까지 가는',
#  '권력을 잡는 그런 이야기인데',
#  '작품이 가지고 있는 색깔, 시대 배경',
#  '캐릭터들이 가지고 있는 트라우마',
#  '트라우마들을 녹여내면서 연기하는 그',
#  '캐릭터 표현력들이 굉장히 좋아서',
#  '의상이나 그 시대가 가지고 있는 배경',
#  '미술 세팅 이런 것들이\n너무 아름다웠던 것 같아요.',
#  '저한테는 배울 게 많아서',
#  '굉장히 애착하는 작품입니다.',
#  '왜냐면 현장에서도',
#  "'피키 블라인더스' 추천을\n많이 하셨고",
#  '킬리언 머피를',
#  '[완전 좋아하지]\n굉장히 좋아하신다고 얘기를 들어서',
#  '저도 빠지게 됐습니다.',
#  "['피키 블라인더스' 꼭 봐야지 메모]",
#  '[오늘 집 가서 봐야지♥]',
#  '[최애 작품은?]\n최애...',
#  '[다 좋은데 어쩌지]\n다 너무 좋아하는데',
#  "근래 'D.P.'를 봤거든요.",
#  "['D.P.' 띵작이지]\n최근에",
#  '[(저도)] 군대를 다녀온 입장이고',
#  '저는 D.P.는 아니었지만',
#  '[헌병대 출신 하준]\n헌병대 출신이어서',
#  '제가 군대에 있을 때는',
#  '[(영화만큼의)]\n부조리, 가혹 행위는 아니었지만',
#  '선배님들은 분명히\n그런 현실을 겪었단 말이죠.',
#  '안타까움, 화도 많이 났었고',
#  '탈영병들을 잡으면서',
#  '그들이 왜 탈영을 하게 됐는지',
#  '공감도 많이 됐었고',
#  '치유되기도 하고',
#  '특히 조현철 선배의 연기가\n[(좋았어요)]',
#  "제 데뷔작이 '차이나타운'인데",
#  '[(조현철 배우가)]\n홍주라는 역할을 하셨었는데',
#  '그때부터 너무 인상 깊게 봤었는데',
#  "'D.P.'에서 또한",
#  '오타쿠인 일병으로 나오다가',
#  '감정의 폭발력이\n굉장히 세게 오더라고요.',
#  '인상 깊었습니다.',
#  "['종이의 집'을 좋아하신다고?]\n'종이의 집'은 넷플릭스 회원이라면",
#  "[넷플릭스 레전드] [모두가 좋아하는 '종이의 집']\n다 보셨고, 다 좋아하실 것 같은데",
#  "어떻게 보면 '종이의 집'으로 인해서",
#  '넷플릭스를 접했고, 빠지게 됐고',
#  '[촬영일 기준 공개 전]\n시즌 5도 나온다고 해서',
#  "['종이의 집' 시즌 5 잘 보고 계시죠?]\n되게 기대하고 있습니다.",
#  "[한국판 '종이의 집' 베를린 역할을 맡으셨는데?]",
#  '[부끄 부끄]\n너무 기대돼.',
#  "사실 저는 '종이의 집'\n엄청 팬이었고",
#  '베를린 역할은 굉장히\n부담스러운 역할이었죠. 저한테는',
#  "[(원작)] '종이의 집'의 베를린은\n조금 냉철하고",
#  '냉혈하고 어떤 면에서는',
#  '악으로 치닫는 경계선에 있는 사람인데',
#  '[(한국판)] 베를린은',
#  '깊은 이유가 있는 역할로 나와서',
#  '전혀 다른 캐릭터가 표현될 것 같고',
#  "'베를린'이라는\n한 인간을 정확히 표현하자.",
#  '[(라는 생각으로)] 준비하고 있어서',
#  '[해수의 베를린도 기대해 주세요♥]\n아마 캐릭터가 굉장히 상반될 거에요.',
#  '제 최애 작품은',
#  "여기서 뽑자면 '로마'",
#  "'로마'를 봤을 때가 '오징어 게임'",
#  '캐스팅 이후였던 것 같은데',
#  "'로마'에 나오는 여자 주인공도\n연기가 처음인",
#  '그녀의 연기를 보면서\n위로받았던 것 같아요.',
#  '뭔가 연기적으로 조금 힘들거나',
#  '고민이 많은 시점에 보면',
#  '리프레시 되는 작품이지 않나라는\n생각이 들어서',
#  "[호연 PICK '로마']\n추천하고 싶습니다.",
#  '장르물을 선배님들이\n다 좋아하시는 것 같아서',
#  "'다크'라는 작품이 있는데",
#  '되게 소재도 신선하고',
#  '작은 아이의 실종 사건으로\n시작이 되는데',
#  '[해수는 스포 시져]',
#  '스포 아니에요.',
#  '[다행]\n아니야?',
#  '서로에게 숨겼던 비밀들이',
#  '점점 폭발하면서\n계속 전개가 되거든요.',
#  '이 마을 전체가\n파괴되는 지경까지 가서',
#  '엄청 흥미롭고\n끊을 수가 없습니다.',
#  '-정재)다크\n-해수)다크     ',
#  "['다크' 정재 마음에 저장♥]",
#  "[아직도 '다크' 찾는 중]\n저는 진짜 얼마 전에 안 건데",
#  '넷플릭스에 모닥불',
#  '그게 뭐예요?',
#  '[(넷플릭스에)] 모닥불을 치면',
#  '모닥불이 타면서 모닥불이 나와요.',
#  '[꿀팁]',
#  '-하준)그냥 나와요 불이?\n-해수)나와요.',
#  '혼술 할 때 아주 예술',
#  "['오징어 게임'을 한마디로?]\n이 정도 게임이면",
#  '굉장히 유혹적이죠.',
#  '선배님 목소리 들으니까',
#  '[심장 정재 올 뻔♥]\n가슴이 약간 뛰었어요.',
#  '제가 굉장히 유혹적이죠.',
#  '저희 작품은 드라마의 힘!',
#  '빼놓을 수 없을 것 같습니다.',
#  '사랑스럽고 아기자기한 공간에 상반되는',
#  '인물들의 삶!',
#  '회가 거듭할수록 드러나는',
#  '반전의 힘!',
#  '저는 굉장히 크다고 생각합니다.',
#  '네 분의 영화 취향이 다양한 것처럼',
#  "'오징어 게임'도",
#  '다양한 장르물과 다양한 이야기와',
#  '다양한 요소들이 많이 담겨있는\n그런 작품인 것 같습니다. ',
#  "'오징어 게임'\n많은 기대 부탁드립니다.",
#  '넷플릭스에서 만나요♥',
#  '[구독하기]']

# %%
str_list = " ".join(texts)
print(str_list), len(str_list)
# Out:
# 저는... '블랙핑크: 세상을 밝혀라'   [정재 취향 궁금하면 드루와]
# 그거 못 했어요! [마이_넷플릭스] 안녕하세요! '오징어 게임'의 이정재 박해수 위하준 정호연입니다. 지금부터 '오징어 게임' 팀의 취향을 가득 담은 '마이 넷플릭스'가 시작됩니다. [기대하라구♥] 게임이 시작됩니다. [마이 넷플릭스]
# [빙고게임♥] 어릴 때 하던 거 말이에요? [맞아요! 그 빙고!] 애들 게임 규칙 단순해. [취향듬뿍 넷플릭스 작품으로 빙고두줄] 그럼 시작합니다. [취향 가득 담아 써 내려가는 빙고판] 저는 해수 선배님이 [(어떤 작품)]  적으실지 알아요. 설마 그걸 적을까? [확신] [헤헷]
# 그걸 적을 것 같아요. 전 정재 선배님이
# 뭘 적을지도 알 것 같아요. [난 다 알지] [진짜?] ['오징어 게임'팀의 넷플릭스 취향은?] [호연이 다 적었지]
# 끝! [넷플릭스 공부하고 왔어요♥]
# 조금 공부하고 왔어요. [호연 예습 칭찬해♥]
# 내가 뭐 봤나. [카운트다운 5, 4] [다급;] [우린 다 썼지]
# [카운트다운 3, 2, 1] 다 못 적었는데 마이클 조던 나오는 거 뭐죠? '마이클 조던: 더 라스트 댄스' [시간이 끝나도 나는 적는다] [순서 정하기]
# 가위바위보! [아쉽다]
# 우와! 시작은 당연히 '오징어 게임' ['오징어 게임' 국룰이지] 저는 '두 교황' [에휴] '두 교황'을 안 적었네.  '피키 블라인더스' 그거 쓰실 줄 알았어요.  어떻게 알았지? '낙원의 밤' [그거 꿀잼인데]  '로마' -정재)로마
# -하준)로마? [에휴] [히히 신난당] 저는 '블랙핑크: 세상을 밝혀라' [선배님 취향 실화예요?]
# 그거 못 했어요! [히히] [넷플속보]
# [이정재, 블링크로 밝혀져 화제] '신세계' 오, 있습니다.  [하하] [아.. '신세계'... 안 적었네...] 장난이 너무 심한 거 아니오! '미생' [오 '미생'] 빙고 한 줄 아니죠? 두 줄? 한 줄이면 진작에 했지! -정재)벌써?
# -하준)진짜요? [헤헷] '다크' Dark요? 독일 드라마인데 [다크 강추]
# 진짜 재밌어요. 저는 '하이웨이맨' 'D.P.' 'D.P.' 있지. '결혼 이야기' '결혼 이야기' '첨밀밀' 정호연 빙고!! [찬란한 빙고 두 줄] [아까비] [호연 빙고 1등♥] [정재의 넷플릭스 취향은?]
# 빙고판에 쓰여져 있는 작품들이 두세 번 이상씩은 본 콘텐츠여서 [정재 취향 16개 캡처 캡처♥]
# 완벽한 제 취향이라고 보셔도 무방할 것 같습니다. [콘텐츠를 선택하는 나만의 팁은?]
# 잘 고르는 팁은 없는 것 같아요. 일단 다 봅니다! 다 보고 나면
# 내가 좋아하는 콘텐츠다. 이 작품은 남에게 추천하지 말아야지. 이렇게 되는 것 같아요. [해수의 넷플릭스 취향은?] [난 내가 취향이야♥]
# '슬기로운 감빵생활'이나 슬빵 명작이죠. [뻔뻔] [두 번째 깨알 홍보ㅋㅋ]
# '사냥의 시간'이라는 작품을 한번 [해수 나오면 다 명작이죠♥]
# 명작이죠. 안 본 소재나 이런 것들을
# 좋아하는 편인 것 같아요. '맨헌트'나 '나르코스'나 접하지 않은 시대의 미술 세팅도 궁금하고 [(미술 세팅)]
# 보는 재미가 있는 것 같아서 [빙고를 통해 알게 되는]
# 보다 보니까 그런 취향이 [내 넷플릭스 취향]
# 제가 좀 많이 찾아보는구나. 이런 생각들이
# 많이 들었던 것 같습니다. [하준의 넷플릭스 취향은?]
# 가장 좋아하는 장르가 두 가지 있는데 누아르랑 가장 현실적인      인간의 본성이나
# 내면 등을 느낄 수 있는 '결혼 이야기'나 '미생' '인간 수업' '사냥의 시간', '신세계' '신세계'는 군대에서 ['신세계' 30번 정주행]
# 30번 본 것 같아요. [듣는 '신세계' 쑥스^^]
# 진짜로 나도 20번은 봤지~ [뿌듯] [선배님♥] [존경합니다♥]
# 남자라면 [호연의 넷플릭스 취향은?]
# 저도 몰랐는데 쓴 걸 보니까 사람 사는 얘기를
# [(좋아하는 것 같아요)] 이야기의 힘이 있는 [맞아 맞아]
# 작품들인 것 같아요. '결혼 이야기'도 그렇고 '첨밀밀'도 그렇고 '내사랑'이라고 에단 호크랑 투박한 사랑 이야기도 너무 좋았고 사랑 이야기가 왜 이렇게 많죠? [왜냐면 호연이가 사랑이니까♥] [최애 작품 추천한다면?]
# 하나만 골라야 해요? '블랙핑크: 세상을 밝혀라' [장꾸 정재] 제가 평상시에 블랙핑크 아주 열렬한 팬은 사실은 아니지만 [평소 친한 제니와 호연]
# 호연 씨하고 제니 씨하고 [제니 안뇽]
# 굉장히 친분이 두텁더라고요. 저희 '오징어 게임' 현장에 [제니+커피차=♥]
# 제니 씨가 커피차와 함께 방문을 하셔서 저도 "우와! 블랙핑크 제니다!" [정재도 신기한 제니♥]
# 신기해하고 '블랙핑크: 세상을 밝혀라'
# 예고편을 보고서 와, 정말 저렇게 치열한 경쟁 속에서
# 블랙핑크가 탄생이 됐고 세계 1등 걸그룹이 되었구나. 저 정도까지 열심히 할 수 있구나. [정재 그렇게 블며들어따..★]
# 블랙핑크의 팬이 됐죠. [블핑 강추]
# 추천도 한번 해주셨어요. [같이 블링크가 됐어요♥]
# 저도 그래서 같이 보고 [다큐멘터리 추천해 주세요]
# 이건 정말 좋은 다큐멘터리라고 얘기할 수 있는 것들이
# 몇 가지가 있는데 '고양이는 건드리지 마라: 인터넷 킬러 사냥' 굉장히 흡입력 있게 구성을 잘하신 것 같아요. 기사로써 읽었을 때의 충격감보다 훨씬 더 충격적인 구성으로 되어 있지 않나
# 그렇게 봅니다. '마이클 조던: 더 라스트 댄스' 보면서도 굉장히 와 이거를 어떻게 이 긴 시간과 여러 감정들을 느끼게 할 수 있는 이야기들을 잘 편집해서 잘 만들었을까 [정재 추천]
# 굉장히 놀라운 작품들이라고 생각해요. 제가 진짜 추천하고 싶은 다큐멘터리는 '헤드스페이스: 숙면이 필요할 때'라는 [그거 좋지]
# 작품이 있어요. 잠이 안 오고 이럴 때 이완 명상도 같이
# 따라 해 보고 하다 보면 어느 순간에 잠이 들더라고요. 그래서 그것도 너무 유용해요! 그래서 추천하고 싶습니다. '익스플레인: 세계를 해설하다'는 짧은 형식의 다큐멘터리이거든요? 주제가 되게 다양해요. 소리, 피부, 주식 시장 질문을 던져주는
# 다큐멘터리인 것 같더라고요. 평소에는 한 번도
# 고민해 보지 못했던 것들을 한 번쯤은 고민하게 되고 궁금한 게 있으면 더 찾아보고 친구들과 얘기하게 될 수 있어서 좋은 영감이 되는 다큐멘터리예요. [추천하고 싶은 작품은?]
# 저는 '피키 블라인더스' [그거일 줄 알았죠]
# 라는 영화가 있는데 1차 세계대전 이후에 셀비 가족이라는 가족들이 마권을 가지고 있던 가족들이 어느 순간 정치계 쪽까지 가는 권력을 잡는 그런 이야기인데 작품이 가지고 있는 색깔, 시대 배경 캐릭터들이 가지고 있는 트라우마 트라우마들을 녹여내면서 연기하는 그 캐릭터 표현력들이 굉장히 좋아서 의상이나 그 시대가 가지고 있는 배경 미술 세팅 이런 것들이
# 너무 아름다웠던 것 같아요. 저한테는 배울 게 많아서 굉장히 애착하는 작품입니다. 왜냐면 현장에서도 '피키 블라인더스' 추천을
# 많이 하셨고 킬리언 머피를 [완전 좋아하지]
# 굉장히 좋아하신다고 얘기를 들어서 저도 빠지게 됐습니다. ['피키 블라인더스' 꼭 봐야지 메모] [오늘 집 가서 봐야지♥] [최애 작품은?]
# 최애... [다 좋은데 어쩌지]
# 다 너무 좋아하는데 근래 'D.P.'를 봤거든요. ['D.P.' 띵작이지]
# 최근에 [(저도)] 군대를 다녀온 입장이고 저는 D.P.는 아니었지만 [헌병대 출신 하준]
# 헌병대 출신이어서 제가 군대에 있을 때는 [(영화만큼의)]
# 부조리, 가혹 행위는 아니었지만 선배님들은 분명히
# 그런 현실을 겪었단 말이죠. 안타까움, 화도 많이 났었고 탈영병들을 잡으면서 그들이 왜 탈영을 하게 됐는지 공감도 많이 됐었고 치유되기도 하고 특히 조현철 선배의 연기가
# [(좋았어요)] 제 데뷔작이 '차이나타운'인데 [(조현철 배우가)]
# 홍주라는 역할을 하셨었는데 그때부터 너무 인상 깊게 봤었는데 'D.P.'에서 또한 오타쿠인 일병으로 나오다가 감정의 폭발력이
# 굉장히 세게 오더라고요. 인상 깊었습니다. ['종이의 집'을 좋아하신다고?]
# '종이의 집'은 넷플릭스 회원이라면 [넷플릭스 레전드] [모두가 좋아하는 '종이의 집']
# 다 보셨고, 다 좋아하실 것 같은데 어떻게 보면 '종이의 집'으로 인해서 넷플릭스를 접했고, 빠지게 됐고 [촬영일 기준 공개 전]
# 시즌 5도 나온다고 해서 ['종이의 집' 시즌 5 잘 보고 계시죠?]
# 되게 기대하고 있습니다. [한국판 '종이의 집' 베를린 역할을 맡으셨는데?] [부끄 부끄]
# 너무 기대돼. 사실 저는 '종이의 집'
# 엄청 팬이었고 베를린 역할은 굉장히
# 부담스러운 역할이었죠. 저한테는 [(원작)] '종이의 집'의 베를린은
# 조금 냉철하고 냉혈하고 어떤 면에서는 악으로 치닫는 경계선에 있는 사람인데 [(한국판)] 베를린은 깊은 이유가 있는 역할로 나와서 전혀 다른 캐릭터가 표현될 것 같고 '베를린'이라는
# 한 인간을 정확히 표현하자. [(라는 생각으로)] 준비하고 있어서 [해수의 베를린도 기대해 주세요♥]
# 아마 캐릭터가 굉장히 상반될 거에요. 제 최애 작품은 여기서 뽑자면 '로마' '로마'를 봤을 때가 '오징어 게임' 캐스팅 이후였던 것 같은데 '로마'에 나오는 여자 주인공도
# 연기가 처음인 그녀의 연기를 보면서
# 위로받았던 것 같아요. 뭔가 연기적으로 조금 힘들거나 고민이 많은 시점에 보면 리프레시 되는 작품이지 않나라는
# 생각이 들어서 [호연 PICK '로마']
# 추천하고 싶습니다. 장르물을 선배님들이
# 다 좋아하시는 것 같아서 '다크'라는 작품이 있는데 되게 소재도 신선하고 작은 아이의 실종 사건으로
# 시작이 되는데 [해수는 스포 시져] 스포 아니에요. [다행]
# 아니야? 서로에게 숨겼던 비밀들이 점점 폭발하면서
# 계속 전개가 되거든요. 이 마을 전체가
# 파괴되는 지경까지 가서 엄청 흥미롭고
# 끊을 수가 없습니다. -정재)다크
# -해수)다크      ['다크' 정재 마음에 저장♥] [아직도 '다크' 찾는 중]
# 저는 진짜 얼마 전에 안 건데 넷플릭스에 모닥불 그게 뭐예요? [(넷플릭스에)] 모닥불을 치면 모닥불이 타면서 모닥불이 나와요. [꿀팁] -하준)그냥 나와요 불이?
# -해수)나와요. 혼술 할 때 아주 예술 ['오징어 게임'을 한마디로?]
# 이 정도 게임이면 굉장히 유혹적이죠. 선배님 목소리 들으니까 [심장 정재 올 뻔♥]
# 가슴이 약간 뛰었어요. 제가 굉장히 유혹적이죠. 저희 작품은 드라마의 힘! 빼놓을 수 없을 것 같습니다. 사랑스럽고 아기자기한 공간에 상반되는 인물들의 삶! 회가 거듭할수록 드러나는 반전의 힘! 저는 굉장히 크다고 생각합니다. 네 분의 영화 취향이 다양한 것처럼 '오징어 게임'도 다양한 장르물과 다양한 이야기와 다양한 요소들이 많이 담겨있는
# 그런 작품인 것 같습니다.  '오징어 게임'
# 많은 기대 부탁드립니다. 넷플릭스에서 만나요♥ [구독하기]
# (None, 5152)

# %% [markdown]
# # # 키워드 추출

# %% [markdown]
# # # 오류
#   * IProgress not found. Please update jupyter and ipywidgets
#     - (해결) pip install ipywidgets

# %%
import numpy as np
import itertools

from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
doc = str_list

# %%
okt = Okt()

tokenized_doc = okt.pos(doc)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'Noun'])

print('품사 태깅 10개만 출력 :',tokenized_doc[:10])
print('')
print('명사 추출 :',tokenized_nouns)
# Out:
# 품사 태깅 10개만 출력 : [('저', 'Noun'), ('는', 'Josa'), ('...', 'Punctuation'), ("'", 'Punctuation'), ('블랙', 'Noun'), ('핑크', 'Noun'), (':', 'Punctuation'), ('세상', 'Noun'), ('을', 'Josa'), ('밝혀라', 'Verb')]
#
# 명사 추출 : 저 블랙 핑크 세상 정재 취향 드루 그거 못 마이 넷플릭스 오징어 게임 의 이정재 위 준 정호 연 지금 오징어 게임 팀 취향 가득 마이 넷플릭스 시작 구 게임 시작 마이 넷플릭스 빙고게임 때 거 말 그 빙고 애 게임 규칙 취향 듬뿍 넷플릭스 작품 빙고 줄 시작 취향 가득 빙고 판 저 해수 선배 작품 설마 확신 적 것 전 정재 선배 뭘 알 것 난 알 진짜 오징어 게임 팀 넷플릭스 취향 호연 끝 넷플릭스 공부 조금 공부 호연 예습 칭찬 내 뭐 카운트다운 급 우린 카운트다운 못 마이클 조던 거 뭐 마이클 조던 더 라스트 댄스 시간 나 순서 정 가위바위보 시작 오징어 게임 오징어 게임 국룰 저 두 교황 두 교황 안 피키 블 인더스 그거 줄 낙원 밤 그거 꿀잼 로마 정재 로마 준 로마 저 블랙 핑크 세상 선배 취향 실화 그거 못 넷플 속보 이정재 블링크 화제 신세계 오 하하 신세계 안 장난 거 미생 오 미생 빙고 줄 두 줄 진작 정재 벌써 준 진짜 다크 요 독일 드라마 다크 강추 진짜 저 하이웨이 맨 결혼 이야기 결혼 이야기 첨밀밀 정호 연 빙고 빙고 두 줄 비 호연 빙고 정재 넷플릭스 취향 빙고 판 작품 번 이상 콘텐츠 정재 취향 개 캡처 캡처 제 취향 무방 것 콘텐츠 선택 나 팁 팁 것 일단 보고 내 콘텐츠 이 작품 남 추천 것 해수 넷플릭스 취향 난 내 취향 감빵 생활 이나 슬빵 명작 뻔뻔 두 깨알 홍보 사냥 시간 작품 한번 해수 명작 명작 안 소재 것 편 것 트 나 코스 나 접 시대 미술 세팅 미술 세팅 재미 것 빙고 통해 알 보 취향 내 넷플릭스 취향 제 좀 생각 것 준 넷플릭스 취향 가장 장르 두 가지 누 아르 가장 현실 인간 본성 내면 등 수 결혼 이야기 나 미생 인간 수업 사냥 시간 신세계 신세계 군대 신세계 번 정 주행 번 것 신세계 쑥스 진짜 번은 뿌듯 선배 존경 남자라면 호연 넷플릭스 취향 저 걸 보 사람 얘기 것 이야기 힘 작품 것 결혼 이야기 도 첨밀밀 도 내사 에단 호크 투 사랑 이야기 사랑 이야기 왜 왜냐면 호연 사랑 최애 작품 추천 하나 골 해 블랙 핑크 세상 장 정재 제 평상시 블랙 핑크 아주 팬 사실 평소 제니 호연 호연 씨 제니 씨 제니 안뇽 친분 저희 오징어 게임 현장 제니 커피차 제니 씨 커피차 방문 저 블랙 핑크 제니 정재 제니 블랙 핑크 세상 예고편 보고서 정말 경쟁 속 블랙 핑크 탄생 세계 걸그룹 저 정도 수 정재 블 블랙 핑크 팬 블핑 강추 추천 한번 블링크 저 보고 다큐멘터리 추천 이건 정말 다큐멘터리 얘기 수 것 몇 가지 고양이 인터넷 킬러 사냥 흡입 구성 것 기사 로써 때 충격 감 더 충격 구성 마이클 조던 더 라스트 댄스 거 이 시간 여러 감정 수 이야기 편집 정재 추천 작품 생각 제 진짜 추천 다큐멘터리 헤드 스페이스 숙면 때 그거 작품 잠 안 때 이완 명상 해 보고 순간 잠 그것 추천 익스 플레인 세계 해설 형식 다큐멘터리 주제가 소리 피부 주식 시장 질문 다큐멘터리 것 평소 번 고민 보지 것 번 고민 게 더 친구 얘기 수 영감 다큐멘터리 추천 작품 저 피키 블 인더스 그거 일 줄 영화 차 세계대전 이후 셀비 가족 가족 마권 가지 가족 순간 정치계 쪽 권력 이야기 작품 가지 색깔 시대 배경 캐릭터 가지 트라우마 트라우마 연기 그 캐릭터 표현 의상 그 시대 가지 배경 미술 세팅 것 것 테 게 애착 작품 왜냐면 현장 피키 블 인더스 추천 킬 리언 머피 완전 얘기 저 피키 블 인더스 꼭 메모 오늘 집 최애 작품 최애 근래 를 띵작 최근 저 군대 입장 저 헌병대 출신 준 헌병대 출신 제 군대 때 영화 부조리 가혹 행위 선배 현실 말 움 화도 탈영병 그 왜 탈영 공감 치유 기도 조현철 선배 연기 제 데뷔 작 차이나타운 조현철 배우 홍주 역할 그때 인상 또한 오타쿠 일병 감정 폭발력 인상 종이 집 종이 집 은 넷플릭스 회원 라면 넷플릭스 레전드 모두 종이 집 것 종이 집 넷플릭스 접 촬영 일 기준 공개 전 시즌 도 종이 집 시즌 보고 계시 한국판 종이 집 베를린 역할 부 부 기대 사실 저 종이 집 팬 베를린 역할 역할 테 원작 종이 집 의 베를린 조금 냉혈 면 악 경계 선 사람 한국판 베를린 이유 역할 전혀 다른 캐릭터 표현 것 베를린 인간 표현 생각 준비 해수 베를린 아마 캐릭터 상반 거 제 최애 작품 여기 로마 로마 를 때 오징어 게임 캐스팅 이후 것 로마 여자 주인공 연기 처음 그녀 연기 위로 것 뭔가 연기 조금 고민 시점 리프 레시 작품 생각 호연 로마 추천 장르 물 선배 것 다크 작품 소재 아이 실종 사건 시작 해수 스포 시 스포 다행 서로 비밀 점점 폭발 계속 전개 이 마을 전체 파괴 지경 흥미 수가 정재 다크 해수 다크 다크 정재 마음 저장 다크 중 저 진짜 얼마 전 안 넷플릭스 모닥불 그게 뭐 넷플릭스 모닥불 치면 모닥불 모닥불 꿀팁 준 그냥 불 해수 혼술 때 아주 예술 오징어 게임 한마디 이 정도 게임 이면 유혹 선배 목소리 심장 정재 뻔 가슴 약간 제 유혹 저희 작품 드라마 힘 수 것 공간 상반 인물 삶 회 거듭 반전 힘 저 생각 네 분 영화 취향 것 오징어 게임 도 장르 물 이야기 요소 작품 것 오징어 게임 기대 넷플릭스 구독

# %% [markdown]
# # # 단어 묶음 개수
# 여기서는 사이킷런의 CountVectorizer를 사용하여 단어를 추출합니다. CountVectorizer를 사용하는 이유는 n_gram_range의 인자를 사용하면 쉽게 n-gram을 추출할 수 있기 때문입니다. 예를 들어, (2, 3)으로 설정하면 결과 후보는 2개의 단어를 한 묶음으로 간주하는 bigram과 3개의 단어를 한 묶음으로 간주하는 trigram을 추출합니다.

# %%
n_gram_range = (2, 3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print('trigram 개수 :',len(candidates))
print('trigram 다섯개만 출력 :',candidates[:5])
# Out:
# trigram 개수 : 1156
# trigram 다섯개만 출력 : ['가득 마이' '가득 마이 넷플릭스' '가득 빙고' '가득 빙고 해수' '가슴 약간']

# %% [markdown]
# # # 다국어 SBERT 로드
# 다음으로 이제 문서와 문서로부터 추출한 키워드들을 SBERT를 통해서 수치화 할 차례입니다. 한국어를 포함하고 있는 다국어 SBERT를 로드합니다.

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
doc_embedding = model.encode([doc])
candidate_embeddings = model.encode(candidates)

# %% [markdown]
# # # 상위 5개의 키워드를 출력

# %%
top_n = 5
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
print(keywords)
# Out:
# ['게임 오징어 게임', '오징어 게임 장르', '취향 오징어 게임', '오징어 게임 한마디', '오징어 게임 이정재']

# %% [markdown]
# # # 다양한 키워 출력
# 5개의 키워드가 출력되는데, 이들의 의미가 좀 비슷해보입니다. 비슷한 의미의 키워드들이 리턴되는 데는 이유가 있습니다. 당연히 이 키워드들이 문서를 가장 잘 나타내고 있기 때문입니다. 만약, 지금 출력한 것보다는 좀 더 다양한 의미의 키워드들이 출력된다면 이들을 그룹으로 본다는 관점에서는 해당 키워드들이 문서를 잘 나타낼 가능성이 적을 수도 있습니다. 따라서 키워드들을 다양하게 출력하고 싶다면 키워드 선정의 정확성과 키워드들의 다양성 사이의 미묘한 균형이 필요합니다.

# %% [markdown]
# ## ## Max Sum Similarity

# %%
def max_sum_sim(doc_embedding, candidate_embeddings, words, top_n, nr_candidates):
    # 문서와 각 키워드들 간의 유사도
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    # 각 키워드들 간의 유사도
    distances_candidates = cosine_similarity(candidate_embeddings, 
                                            candidate_embeddings)

    # 코사인 유사도에 기반하여 키워드들 중 상위 top_n개의 단어를 pick.
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # 각 키워드들 중에서 가장 덜 유사한 키워드들간의 조합을 계산
    min_sim = np.inf
    candidate = None
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

# %%
max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=10)
# Out:
# ['취향 취향 감빵', '선배 진짜 오징어', '빙고게임 빙고 게임', '호연 넷플릭스 공부', '오징어 게임 장르']

# %% [markdown]
# ### ### 더 다양한 키워드 5개

# %%
max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=30)
# Out:
# ['블링크 보고 다큐멘터리', '취향 감빵', '게임 시작', '게임 장르 이야기', '선배 진짜 오징어']

# %% [markdown]
# ## ## Maximal Marginal Relevance

# %%
def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.2)
# Out:
# ['오징어 게임 이정재', '호연 넷플릭스 공부', '오징어 게임 한마디', '취향 오징어 게임', '하하 신세계 장난']

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.7)
# Out:
# ['오징어 게임 이정재', '고양이 인터넷 킬러', '종이 베를린', '공부 조금 공부', '결혼 이야기 첨밀밀']

# %% [markdown]
# # # 화장품 영상으로 키워드 추출

# %% [markdown]
# ## ## 유튜브 자막 추출

# %%
# 타겟 영상 : https://www.youtube.com/watch?v=VOKEpxFu2_8
from youtube_transcript_api import YouTubeTranscriptApi
srt = YouTubeTranscriptApi.get_transcript("VOKEpxFu2_8", languages=['ko'])

###
text = ''
 
for i in range(len(srt)):
    text += srt[i]['text'] + ' ' # text 부분만 가져옴
    
text_ = text.replace(' ','')

###
texts = list()
 
for i in range(len(srt)):
  texts.append(srt[i]['text']) 


###
str_list = " ".join(texts)

str_list
# Out:
# '새로 나온 보다나 40mm 물결 고데기 예뻐 보이긴 하는데 9만 원이나 한다고? 살까 말까 고민하시는 분들, 다른 고데기와 차이점이 궁금하신 분들 많으시죠? 셀프 헤어스타일링 능력자 저 김습습이 보다나 물결 고데기를 솔직하게 리뷰하고 물결 웨이브 예쁘게 넣는 팁 그리고 또 다른 고데기들이랑 비교도 해드릴게요. 안녕하세요, 여러분! 김습습입니다. 여러분! 오늘은 제가 새로 나온 고데기 하나 리뷰해 보려고 하는데요. 출시되자마자 품절 대란을 일으키고 있는 보다나의 트리플 플로우 물결고데기 40mm입니다. 크리미블루 컬러이고요. 물결펌 전용으로 나온 제품이에요. 가격은 9만 원에 판매를 하고 있습니다. 저는 이거를 인스타그램 협찬을 받았었는데요. 여러분들이 많이 궁금해 하시더라고요. 그래가지고 제가 유튜브는 아무런 경제적 대가 없이 촬영을 하고 있습니다. 저는 이거를 지금 출시되기 전부터 사용을 해가지고 거의 한 2주 정도 먼저 사용을 해봤었는데요. 물결펌 전용으로 나온 제품이어가지고 크기가 살짝 이렇게 크게 나왔더라고요. 이렇게 제품을 보시면 봉고데기 반 개를 한 쪽씩 나눠 붙인 모양으로 되어 있어요. 그래서 그냥 이렇게 머리를 집기만 하면 물결이 나올 수 있도록 그렇게 만들어진 고데기인데요. 제가 간단하게 장단점을 말씀드리자면 첫 번째 장점은 정말 쉬워서 곰손도 가능합니다. 그래서 간단하고 쉽고 빠르게 물결 웨이브를 넣을 수 있다는 장점이 있고요. 단점으로는 일단 좀 무거워요. 일반 고데기에 비해서 좀 무거운 편이고 그리고 사용하다 보면은 이쪽 부분이 좀 많이 뜨거워지는 편이더라고요. 일반 고데기와는 다르게 이쪽 부분이 좀 많이 뜨거워지는 느낌이었어요. 그래서 손 약간 데면 화상 입을 것 같은 느낌적인 느낌이 들었고요. 그러면 제가 이 제품을 사용하는 방법을 자세하게 알려드리고 팁들을 알려드리면서 장단점에 대해서 조금 더 설명을 해드릴게요. 일단 이 제품은 전원 버튼이 이렇게 있고요. 이거를 꼭 누르면 켜지고 살짝살짝 눌러서 온도 조절을 할 수가 있습니다. 저는 이 물결펌 고데기를 할 때는 보통 200도로 해주는 편이에요. 높은 온도로 할수록 컬이 좀 살아나기 때문에 난 좀 더 자연스러운 흐르는 물결을 만들고 싶다 하시는 분들은 조금 한 160도에서 180도 정도로 사용하시면 될 것 같아요. 일단 우리가 머리숱이 되게 많잖아요. 이거를 한 번에 이런 식으로 하면 되게 안 예쁘게 나와요. 그래서 최소 두 번 정도로 나눠가지고 해줘야 됩니다. 일단 반 정도를 머리를 고정을 시켜줄게요. 이 상태에서 아래 머리부터 해볼 건데요. 물결 웨이브를 하실 때 가장 중요한 포인트 하나 알려드릴게요. 뭐냐면 바로 여러분! 제일 위에 물결이 안쪽으로 들어가야 됩니다. 이게 왼쪽 머리를 하실 때는 이 정도 좀 잡아주세요. 이게 판이 넓어가지고 좀 많이 잡아도 되는 편이거든요, 일반 고데기에 비해서. 그렇다고 너무 많이 잡게 되면 뭔가 진짜 집은 느낌이 나서 안 예쁠 수가 있어요. 그래서 한 이 정도, 한 4cm? 4cm 정도 잡아서 하시면 됩니다. 왼쪽 머리를 하실 때는 왼손으로 머리를 잡으시고 오른손으로 고데기를 잡으시고요. 위에서부터 해주시면 됩니다. 집어서 하면은 이제 이렇게 컬이 생기죠? 이렇게 컬이 생기는데 무조건 안쪽으로 먼저 들어가 줘야 됩니다, 머리가. 이게 반대로 사용하시면 찍힌 자국이 남을 확률이 있어가지고 제일 위에 머리는 무조건 안으로 해주세요. 그리고 이렇게 한 다음에 그 웨이브가 끝나는 지점에서 한 번 더 집어주시면 됩니다, 이렇게. 그리고 이렇게 해주실 때는 조금 밀어가지고 컬이 식으면서 더 탱글하게 유지되게 이렇게 해주세요. 그리고 또 여기, 컬이 좀 유지가 되도록. 이런 식으로 계속 그냥 너무 쉽죠? 그냥 집어주시기만 하면 됩니다. 이게 웨이브를 좀 탱글탱글하게 넣고 싶다 하시면 조금 더 잘게 해주시면 되고요. 웨이브를 조금 느슨하게 하고 싶다 하시면 온도를 낮추셔도 되는데 이렇게 집어주실 때 조금 더 간격을 두고 집어주시면 더 흐느적 흐느적거리는 웨이브가 됩니다. 너무 쉬워가지고 뭐 이거는 이 정도 팁을 드릴 수 있을 것 같아요. 이런 식으로 하면 너무 쉽게 웨이브가 됐죠? 나머지 머리도 해볼게요. 이 정도는 너무 많아요. 이거를 반 정도로 나눠가지고 해주는 게 좋을 것 같아요. 아까처럼 왼쪽 머리하실 때 왼손으로 머리를 잡으시고 오른손으로 위에부터 이렇게 집어줍니다. 진짜 너무 쉽죠? 이거는 진짜 곰손분들도 무조건 할 수 있어요. 자국도 안 남고 고데기 컬도 일정하게 이렇게 들어가는 편이어가지고 정말 간단하게 물결 웨이브를 하실 수 있습니다. 이런 식으로. 오른쪽 머리를 하실 때도 왼손으로 머리를 잡아주시고 그리고 오른손으로 고데기를 잡아주세요, 이렇게 똑같이. 이런 식으로 해주셔야 제일 위에 웨이브가 안쪽으로 들어가지게 됩니다, 여러분. 이렇게 해서 똑같은 방법으로 이런 식으로 해주시면 됩니다. 이렇게 무조건 제일 윗단이 안쪽으로 들어가야 머리가 예쁘게 됩니다, 여러분. 그리고 왼쪽은 안쪽으로 들어갔는데 오른쪽은 바깥쪽으로 들어가 버리면 안 맞잖아요. 그래서 안쪽으로 무조건 이게 진짜 제일 포인트예요. 그리고 하실 때 컬을 조금 더 예쁘게 탱글탱글하게 넣고 싶다 하시면 아까 말씀드린 것처럼 조금 컬을 이렇게 동글동글하게 해주면서 신경 써 주면서, 막 그냥 콕콕콕 집는 게 아니라 집으면서도 아까 넣었던 컬이 좀 유지되도록 이런 식으로 해주시면 조금 더 탱글탱글한 웨이브가 됩니다. 제가 아까 말씀드렸잖아요. 이걸 만약에 바깥으로 하면 어떻게 되냐. 바깥으로 하면 여기 머리를 보시면 여기 이렇게 자국 남은 거 보이시죠? 그래서 안에 머리면 상관없겠지만 윗머리까지 이렇게 해버리면 겉에 이런 자국이 남으면 너무 안 예쁘겠죠? 그래서 무조건 안쪽으로 먼저 해주셔야 됩니다, 꼭! 지금 이렇게 아랫단만 해줬는데 되게 예쁘게 됐죠? 이런 식으로 일정하게 컬을 넣을 수가 있어가지고 진짜 미용실에서 한 것 같은 그런 느낌이 듭니다. 이 보다나의 물결펌 전용 고데기가 나오기 전에는 저는 판고데기나 봉고데기 사용해서 물결 웨이브를 많이 넣어줬었는데요. 뭐 이런 제품도 있었고요. 이런 식으로 다른 여러 가지 고데기랑 비교를 해서 제가 말씀을 드릴게요. 일단 이 고데기는 한때 엄청 핫했었죠? 중국산 고데기였어요. 웨이브가 잘 들어가긴 하는데 머릿결이 너무 많이 상하더라고요. 진짜 무슨 불에 탄 것처럼 그렇게 스타일링이 돼가지고 이 고데기는 그 이후로 잘 사용하지 않았고요. 그리고 이 봉고데기로 물결 웨이브 넣는 방법이 있는데요. 제가 영상으로도 한번 올려놨어요. 여기 눌러서 한번 봐주시고요. 이 방법은 제가 쉽게 설명은 해드렸지만 아무래도 수준급으로 셀프 헤어 스타일링을 하시는 분들에게는 정말 예쁘게 웨이브를 넣을 수 있는 방법이긴 하지만 조금 시간도 오래 걸리고, 그리고 컬도 잡기가 어렵기 때문에 곰손이신 분들은 아마 이 봉고데기로는 웨이브를 넣기 어려우실 것 같고요. 또 우리가 많이 사용하는 이런 판고데기 물결 웨이브를 또 많이 하시는 걸로 알고 있어요. 그래서 제가 이 윗부분을 반은 물결 웨이브 전용 고데기로 반은 이 판고데기로 해가지고 어떻게 다른지 보여드릴게요, 여러분. 앞머리는 제일 마지막에 해주도록 할게요. 먼저 왼쪽은 이 보다나 고데기 사용해서 똑같이 아까처럼 해줄 거예요. 그냥 이렇게 머리를 넣고 집어주기만 하면 되게끔. 앞머리를 해주실 때는 어렵게 생각하지 마시고 이렇게 물결이 들어간 경우에 앞머리도 물결을 해줘야 안 어색하거든요. 만약에 고데기로 이런 식으로 해주면 조금 어색할 수 있어가지고 그냥 저는 이 물결 고데기로 해주는 편입니다. 이런 식으로 집어주시면 웨이브가 들어가는데요. 뭔가 좀 이상한 것 같잖아요. 이 머리를 귀 뒤로 꽂고 있다가 나중에 풀어주면 되게 자연스럽게 돼요. 그래서 이런 식으로 꽂고 계셔 주시면 됩니다. 그리고 이 고데기를 끌 때는 이거 꼭 누르면 꺼지는데요. 이게 안전을 위해서 고데기를 켠 지 1시간이 되면 자동적으로 꺼진다고 합니다. 이거는 진짜 좋은 것 같아요. 이렇게 왼쪽 머리는 보다나 고데기로 다 해줬고요. 오른쪽 머리는 이제 판고데기로 웨이브를 넣어줄게요. 아까 제가 알려드렸다시피 ...

# %% [markdown]
# # # 키워드 추출

# %%
import numpy as np
import itertools

from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
doc = str_list

###
okt = Okt()

tokenized_doc = okt.pos(doc)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'Noun'])

###
n_gram_range = (2, 3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

###
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
doc_embedding = model.encode([doc])
candidate_embeddings = model.encode(candidates)

# %%
top_n = 5
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
print(keywords)
# Out:
# ['수가 진짜 미용실', '비교 여러분 김습습', '헤어스타일 댓글', '댓글 사랑', '헤어스타일 능력자']

# %%
def max_sum_sim(doc_embedding, candidate_embeddings, words, top_n, nr_candidates):
    # 문서와 각 키워드들 간의 유사도
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    # 각 키워드들 간의 유사도
    distances_candidates = cosine_similarity(candidate_embeddings, 
                                            candidate_embeddings)

    # 코사인 유사도에 기반하여 키워드들 중 상위 top_n개의 단어를 pick.
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # 각 키워드들 중에서 가장 덜 유사한 키워드들간의 조합을 계산
    min_sim = np.inf
    candidate = None
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=10)
# Out:
# ['헤어스타일 능력자 김습습', '수가 진짜 미용실', '비교 여러분 김습습', '헤어스타일 댓글', '댓글 사랑']

# %%
max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=30)
# Out:
# ['리뷰 한마디 물결', '제품 사용 방법', '물결 장단점 장점', '여러분 김습습 여러분', '헤어스타일 능력자 김습습']

# %%
def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.2)
# Out:
# ['헤어스타일 능력자', '댓글 사랑', '수가 진짜 미용실', '비교 여러분 김습습', '헤어스타일 능력자 김습습']

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.7)
# Out:
# ['헤어스타일 능력자', '가격 판매 인스타그램', '후회 제품 가격', '중국산 웨이브', '흐느적 흐느 거리']
