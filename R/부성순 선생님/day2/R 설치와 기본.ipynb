# %% [markdown]
# # 전통적인 통계방법론을 적용한 기계학습
#   * 통계수학적 이론에 배경, 이미 잘 확립
#   * 사이킷런 파이썬 패키지, R은 대부분
#
# # 인공신경망 알고리즘을 적용한 기계학습
#   * 최소한의 통계이론만 적용
#   * 수학적 이론
#
# # 인공지능과 관련된 수학적 알고리즘을 제공
#   * 텐서플로우 패키지(초반에는 파이썬, C만 가능 / 지금은 R도 가능)

# %% [markdown]
# # 교재 ~p.31
#
# # R설치
#   * 구글에서 'R 다운로드' 첫번째 검색 결과
#   * program files - R - 속성 - 보안 - User 계정에 모든 권한 추가
#
# # R 버전 변경시
#   * 반드시 제거하고
#   * 프로그램 설치된 폴더에서 잔여폴더 제거하고
#   * R 다른 버저으로 설치
#
# # R설치 후에 R스튜디오 설치해야함
#
# # R은 인터페이스가 별로 안좋다.
#   * 메모리 사용량이 R 스튜디오보다 작다
#
# # R - 편집 - GUI 설정 - Gulimche
#
# # p.43~52 까지는 다음에

# %% [markdown]
# # R 에서 '>' 가 나와야 이전 연산이 완료되고 다음 연산이 준비된 상태
#   * 어떤 error가 있는지에 대해서 설명이 없이 '+(덧셈)'가 나온다.
#
# # a=2 표현하는 방법
#   * a<-2
#
# # 파이썬
#   * a=[2,3,4,3]
#   * len(a)
# # R
#   * a=c(2,3,4,3)
#   * length(a)

# %% [markdown]
# # R 에서는 기본적으로 구조부터 확인해야 한다.
#     * str(a)
#
# # table(a)
#     * a 리스트 안에
#
# # 여러가지 시각화
#     * plot(a)
#
# # plot(table(a))
#
# # boxplot(a)
#
# [파일 - 새 스크립트]
#
# # 스크립트 창에서 작성한 코드는 커서를 그 줄에 두고 ctrl+R 또는 F5
# # 여러줄 명령은 블럭지정 후 Ctrl+R 또는 F5
# # 다른이름으로 저장 - 확장자를 txt로 바꿔도 문제 없다.
#
# [중점사항 : R의 factor에 대하여]
#
# # 숫자
#   * 정수
#   * 실수
#
# # 문자 : 한 글자
# # 문자열 : 한 글자 이상
#
# # 문자
#   * 집계 의미 X (이를 charactor 라고 한다.)
#     - 문자열 처리 O
#   * 집계 의미 O (이를 factor 라고 한다.)
#     - 나누기 등 X
#     - 명목형 변수

# %% [markdown]
# # p.116~
#
# # 메트릭스 : 인덱스로 작업
# # 데이터프레임 : 제목
